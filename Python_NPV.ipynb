# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_table("companies (1).txt")
df1.head()

# df1.info()
df1["permalink"].nunique()
# Out:
# 66368

# %%
df=pd.read_csv("pj1.csv",encoding="unicode_escape")
df.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %% [markdown]
# q1. Reading the Rounds2, companies.txt files

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114949 non-null  object
#  1   funding_round_permalink  114949 non-null  object
#  2   funding_round_type       114949 non-null  object
#  3   funding_round_code       31140 non-null   object
#  4   funded_at                114949 non-null  object
#  5   raised_amount_usd        94959 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %% [markdown]
# 2. How many unique companies are present in rounds2?

# %%
df["company_permalink"].nunique()
# Out:
# 90247

# %%
df1["permalink"].nunique()
# Out:
# 66368

# %% [markdown]
# 4.Write the code to convert companies[‘permalink’] and Round2[‘company_permalink’] columns
# to uppercase.

# %%
def mapp(x):
    if x=="company_permalink":
        return x.upper()
    else:
        return x
df.columns=list(map(mapp,df.columns))
df.head()
# Out:
#                      COMPANY_PERMALINK  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %%
df1["permalink"]=df1["permalink"].str.upper()

# %%
df1.head()
def app(x):
    if x=="permalink":
        return x.upper()
    else:
        return x
df1.columns=list(map(app,df1.columns))
df1.head()
# Out:
#                              PERMALINK                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 3                /ORGANIZATION/0-6-COM                 0-6.com
# 4       /ORGANIZATION/004-TECHNOLOGIES        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %% [markdown]
# 5. Are there any companies in the rounds2 file which are not present in companies.txt ?

# %%
d=(set(df["COMPANY_PERMALINK"])).difference(set(df1["PERMALINK"]))
pd.DataFrame(d)
# Out:
#                                                     0
# 0                        /organization/federatedmedia
# 1                              /organization/hipvilla
# 2                              /organization/camstent
# 3      /organization/internet-college-internation-s-l
# 4                             /organization/dishcrawl
# ...                                               ...
# 45160              /organization/ciphergraph-networks
# 45161                          /organization/in2bones
# 45162                      /organization/malwarebytes
# 45163                          /organization/merkatic
# 45164                            /organization/cambly
#
# [45165 rows x 1 columns]

# %%
s1=set(df["COMPANY_PERMALINK"])
s2=set(df1["PERMALINK"])
s3=s1.difference(s2)
pd.DataFrame(s3)
# Out:
#                                                     0
# 0                        /organization/federatedmedia
# 1                              /organization/hipvilla
# 2                              /organization/camstent
# 3      /organization/internet-college-internation-s-l
# 4                             /organization/dishcrawl
# ...                                               ...
# 45160              /organization/ciphergraph-networks
# 45161                          /organization/in2bones
# 45162                      /organization/malwarebytes
# 45163                          /organization/merkatic
# 45164                            /organization/cambly
#
# [45165 rows x 1 columns]

# %%
s1=df["COMPANY_PERMALINK"] 
s2=df1["PERMALINK"]
a=set(s1)
b=set(s2)
df3=a.difference(b)
len(df3)
pd.DataFrame(df3)
# Out:
#                                                     0
# 0                        /organization/federatedmedia
# 1                              /organization/hipvilla
# 2                              /organization/camstent
# 3      /organization/internet-college-internation-s-l
# 4                             /organization/dishcrawl
# ...                                               ...
# 45160              /organization/ciphergraph-networks
# 45161                          /organization/in2bones
# 45162                      /organization/malwarebytes
# 45163                          /organization/merkatic
# 45164                            /organization/cambly
#
# [45165 rows x 1 columns]

# %% [markdown]
# 6. Merge the two data frames so that all variables (columns) in the company's frame are added
# to the rounds2 data frame. Name the merged frame master_dataframe. How many observations
# are present in master_frame ?

# %%
df.columns
# Out:
# Index(['COMPANY_PERMALINK', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd'],
#       dtype='object')

# %%
df.columns=['PERMALINK', 'funding_round_permalink', 'funding_round_type',
       'funding_round_code', 'funded_at', 'raised_amount_usd']
df.head()
# Out:
#                              PERMALINK  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %%
master_dataframe=pd.merge(df1,df,how="outer",right_index=True,left_index=True)
master_dataframe.head()
# Out:
#                            PERMALINK_x                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 3                /ORGANIZATION/0-6-COM                 0-6.com
# 4       /ORGANIZATION/004-TECHNOLOGIES        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at  \
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010
#
#                            PERMALINK_y  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %% [markdown]
# 7. Write the code to drop the redundant column ‘'company_permalink' from the

# %%
master_dataframe.drop(columns="PERMALINK_x")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 master_dataframe.drop(columns="PERMALINK")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['PERMALINK'] not found in axis"

# %% [markdown]
# 8. Write the code to find the percentage missing value (column-wise) in master_dataframe. Drop
# unnecessary columns.

# %%
s1=master_dataframe.isnull().sum()*100/len(master_dataframe)
s1

# %% [markdown]
# 9. Create a pivot table to compare the mean and median values for ‘raised_amount_usd’ and
# ‘funding_round_type’ across different funding round categories..

# %%
pd.pivot_table(master_dataframe,index=("funding_round_type"),values=(["raised_amount_usd"]) , aggfunc=["mean"])

# %%
10. Filter the master_dataframe on ‘raised_amount_usd’ such as ‘raised_amount_usd’ lie
between 4 Millions to 15 Millions

# %%
m1=master_dataframe[(master_dataframe["raised_amount_usd"]>4000000) & (master_dataframe["raised_amount_usd"]<15000000)]
m1.head()

# %% [markdown]
# 11.Identify the top 9 countries in terms of highest investment in ‘venture’ fund type.

# %%
m1=master_dataframe.groupby("country_code")["raised_amount_usd"].sum()
m1.nlargest(9).to_frame()

# %% [markdown]
# 12. Create the ‘main_category’ column by extracting the main sector using the column
# ‘category_list’.
# Hint - Use the Lambda function or string function

# %%
f1=[lambda x:x.split("|")[0]if type(x)==str else x]

# %%
master_dataframe["main_category"]=master_dataframe["category_list"].apply(f1)
master_dataframe.head()

# %% [markdown]
# 13. Using the user defined function convert the ‘rasied_amount_used’ column into a categorical
# column as followa) If the amount is less than 5 Millions then recode as TypeA.
# b) If the amount is greater than 5 Millions and less than 7 Millions then recode as TypeB.
# c) If the amount is greater than 7 Millions then recode as TypeC

# %%
master_dataframe["raised_amount_usd"]

# %%
def usd(x):
    if x>5000000 and x<=7000000:
        return "TypeB"
    elif x<=5000000:
        return "TypeA"
    elif x>7000000:
        return "TypeC"
    else:
        return x

    
master_dataframe["raised_amount_usd"]=list(map(usd,master_dataframe["raised_amount_usd"]))

# %%
master_dataframe.head(15)
# Out:
#                                    PERMALINK                         name  \
# 0                        /Organization/-Fame                        #fame
# 1                     /Organization/-Qounter                     :Qounter
# 2        /Organization/-The-One-Of-Them-Inc-       (THE) ONE of THEM,Inc.
# 3                      /Organization/0-6-Com                      0-6.com
# 4             /Organization/004-Technologies             004 Technologies
# 5           /Organization/01Games-Technology           01Games Technology
# 6        /Organization/0Ndine-Biomedical-Inc       Ondine Biomedical Inc.
# 7                       /Organization/0Xdata                       H2O.ai
# 8                            /Organization/1                     One Inc.
# 9                  /Organization/1-2-3-Listo                  1,2,3 Listo
# 10                     /Organization/1-4-All                      1-4 All
# 11            /Organization/1-618-Technology             1.618 Technology
# 12               /Organization/1-800-Dentist                1-800-DENTIST
# 13               /Organization/1-800-Doctors                1-800-DOCTORS
# 14  /Organization/1-800-Publicrelations-Inc-  1-800-PublicRelations, Inc.
#
#                           homepage_url  \
# 0                   http://livfame.com
# 1               http://www.qounter.com
# 2                  http://oneofthem.jp
# 3                   http://www.0-6.com
# 4    http://004gmbh.de/en/004-interact
# 5               http://www.01games.hk/
# 6                 http://ondinebio.com
# 7                       http://h2o.ai/
# 8                   http://whatis1.com
# 9              http://www.123listo.com
# 10                                 NaN
# 11  http://www.Homeandcondogallery.com
# 12          http://www.1800dentist.com
# 13              http://1800doctors.com
# 14  http://www.1800publicrelations.com
#
#                                         category_list     status country_code  \
# 0                                               Media  operating          IND
# 1   Application Platforms|Real Time|Social Network...  operating          USA
# 2                                   Apps|Games|Mobile  operating          NaN
# 3                                         Curated Web  operating          CHN
# 4                                            Software  operating          USA
# 5                                               Games  operating          HKG
# 6                                       Biotechnology  operating          CAN
# 7                                           Analytics  operating          USA
# 8                                              Mobile  operating          USA
# 9                                          E-Commerce  operating          CHL
# 10                       Entertainment|Games|Software  operating          USA
# 11                 Networking|Real Estate|Web Hosting  operating          USA
# 12                                Health and Wellness  operating          USA
# 13                                Health and Wellness  operating          USA
# 14          Internet Marketing|Media|Public Relations  operating          USA
#
#    state_code                 region               city  founded_at  \
# 0          16                 Mumbai             Mumbai         NaN
# 1          DE             DE - Other      Delaware City  04-09-2014
# 2         NaN                    NaN                NaN         NaN
# 3          22                Beijing            Beijing  01-01-2007
# 4          IL  Springfield, Illinois          Champaign  01-01-2010
# 5         NaN              Hong Kong          Hong Kong         NaN
# 6          BC              Vancouver          Vancouver  01-01-1997
# 7          CA            SF Bay Area      Mountain View  01-01-2011
# 8          CA            SF Bay Area      San Francisco  01-08-2011
# 9          12               Santiago         Las Condes  01-01-2012
# 10         NC             NC - Other  Connellys Springs         NaN
# 11         FL                Orlando            Orlando  07-12-2013
# 12         CA            Los Angeles        Los Angeles  01-01-1986
# 13         NJ                 Newark             Iselin  01-01-1984
# 14         NY          New York City           New York  24-10-2013
#
#                       COMPANY_PERMALINK  \
# 0                   /organization/-fame
# 1                /ORGANIZATION/-QOUNTER
# 2                /organization/-qounter
# 3   /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                 /organization/0-6-com
# 5        /ORGANIZATION/004-TECHNOLOGIES
# 6      /organization/01games-technology
# 7   /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8   /organization/0ndine-biomedical-inc
# 9                  /ORGANIZATION/0XDATA
# 10                 /organization/0xdata
# 11                 /ORGANIZATION/0XDATA
# 12                 /organization/0xdata
# 13                      /ORGANIZATION/1
# 14                      /organization/1
#
#                             funding_round_permalink funding_round_type  \
# 0   /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1   /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2   /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3   /funding-round/650b8f704416801069bb178a1418776b            venture
# 4   /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 5   /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 6   /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 7   /funding-round/2b9d3ac293d5cdccbecff5c8cb0f327d               seed
# 8   /funding-round/954b9499724b946ad8c396a57a5f3b72            venture
# 9   /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
# 10  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 11  /funding-round/ae2a174c06517c2394aed45006322a7e            venture
# 12  /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e            venture
# 13  /funding-round/03b975068632eba5bfdb937ec8c07a68               seed
# 14  /funding-round/5de6d8828aef7d925d97918d15727670        undisclosed
#
#    funding_round_code   funded_at raised_amount_usd          main_category
# 0                   B  05-01-2015             TypeC                  Media
# 1                   A  14-10-2014               NaN  Application Platforms
# 2                 NaN  01-03-2014             TypeA                   Apps
# 3                   B  30-01-2014             TypeA            Curated Web
# 4                   A  19-03-2008             TypeA               Software
# 5                 NaN  24-07-2014               NaN                  Games
# 6                 NaN  01-07-2014             TypeA          Biotechnology
# 7                 NaN  11-09-2009             TypeA              Analytics
# 8                 NaN  21-12-2009             TypeA                 Mobile
# 9                 NaN  22-05-2013             TypeA             E-Commerce
# 10                  B  09-11-2015             TypeC          Entertainment
# 11                NaN  03-01-2013             TypeA             Networking
# 12                  A  19-07-2014             TypeC    Health and Wellness
# 13                NaN  05-02-2014             TypeA    Health and Wellness
# 14                NaN  05-02-2013               NaN     Internet Marketing
